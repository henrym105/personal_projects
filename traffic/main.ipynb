# %%
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt

from glob import glob

import IPython.display as ipd
from tqdm.notebook import tqdm

import subprocess
import ffmpeg

# %%
# video_file = '/Users/Henry/Desktop/personal_projects/traffic/Commonwealth_traffic.MOV'
video_file = '/Users/Henry/Desktop/personal_projects/traffic/video2.mp4'


# subprocess.run(['ffmpeg', '-i', video_file, '-qscale', '0', 'CommAve.mp4'])
# ffmpeg -i /Users/Henry/Desktop/personal_projects/traffic/Commonwealth_traffic.MOV -qscale 0 CommAve.mp4

# %%
# !ls -GFlash --color

# %%
ipd.Video(video_file)
# Out:
# <video src="/Users/Henry/Desktop/personal_projects/traffic/video2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# load in video capture
cap = cv2.VideoCapture(video_file)

# %%
# Video metadata
totalframes = cap.get(cv2.CAP_PROP_FRAME_COUNT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = cap.get(cv2.CAP_PROP_FPS)

print("total frames:", int(totalframes))
print("width:", int(width))
print("Height:", int(height))
print("fps:", round(fps, 2))
# Out:
# total frames: 150
# width: 640
# Height: 360
# fps: 29.97

# %%
ret, img = cap.read()
# ret will return True until we reach the end of the video
# (i.e. it is true that there is still a frame in the video
print(f'Returned {ret} and img of shape {img.shape}')
# Out:
# Returned True and img of shape (360, 640, 3)

# %% [markdown]
# ### Print out first frame of video

# %%
plt.imshow(img)

# helper function to convert from BGR colors to RGB format
def display_cv2_img(img, figsize=(8,8)):
    img_ = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    fig, ax = plt.subplots(figsize=figsize)
    ax.imshow(img_)
    ax.axis("off")

display_cv2_img(img)

# %% [markdown]
# ### Display a grid of frames from the video

# %%
fig, axs = plt.subplots(5, 5, figsize = (30,20))
axs = axs.flatten()
plt.show()

cap = cv2.VideoCapture(video_file)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

img_index = 0

for frame in range(n_frames):
    ret, img = cap.read()
    if ret == False:
        break
    if frame %100 == 0:
        axs[img_index].inshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/Henry/Desktop/personal_projects/traffic/main.ipynb Cell 11 in <cell line: 10>()
#      <a href='vscode-notebook-cell:/Users/Henry/Desktop/personal_projects/traffic/main.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     break
#      <a href='vscode-notebook-cell:/Users/Henry/Desktop/personal_projects/traffic/main.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a> if frame %100 == 0:
# ---> <a href='vscode-notebook-cell:/Users/Henry/Desktop/personal_projects/traffic/main.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     axs[img_index].inshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#
# AttributeError: 'AxesSubplot' object has no attribute 'inshow'
